# %%
import pandas as pd
import numpy as np
from datetime import datetime as dt
import calendar
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline
from matplotlib import rcParams
import warnings

# %%
df = pd.read_csv("../csv/exported_queries/Distribuzione_temporale_eventi_fix_with_members.csv")
df.head()
# Out:
#    Unnamed: 0             ID           time country state     lon    lat  \
# 0           0      260269871  5317552800000      us    ca -118.33  33.87
# 1           1      260260779  3384554400000      us    wa -117.43  47.67
# 2           2  ztbltqyxcdbbc  2150290800000      us    tn  -86.72  36.08
# 3           3      260361735  1924992000000      sg    sg  103.85   1.30
# 4           4      260337211  1924992000000      sg    sg  103.85   1.30
#
#    partecipanti         timezone_str   datetime_timezoned
# 0             1  America/Los_Angeles  04/07/2138 10:00:00
# 1             2  America/Los_Angeles  01/04/2077 18:00:00
# 2             1      America/Chicago  20/02/2038 09:00:00
# 3             1       Asia/Singapore  01/01/2031 08:00:00
# 4             1       Asia/Singapore  01/01/2031 08:00:00

# %%
df.drop(columns = "Unnamed: 0", inplace = True)

# %%
tmp = df['datetime_timezoned'].str.split(" ", n = 1, expand = True) #create distinct columns date and time
df['day'] = [calendar.day_name[dt.strptime(date, '%d/%m/%Y').weekday()] for date in tmp[0]] #transform date into day
df['dtime'] = tmp[1] #take time
df.head()
# Out:
#               ID           time country state     lon    lat  partecipanti  \
# 0      260269871  5317552800000      us    ca -118.33  33.87             1
# 1      260260779  3384554400000      us    wa -117.43  47.67             2
# 2  ztbltqyxcdbbc  2150290800000      us    tn  -86.72  36.08             1
# 3      260361735  1924992000000      sg    sg  103.85   1.30             1
# 4      260337211  1924992000000      sg    sg  103.85   1.30             1
#
#           timezone_str   datetime_timezoned        day     dtime
# 0  America/Los_Angeles  04/07/2138 10:00:00     Friday  10:00:00
# 1  America/Los_Angeles  01/04/2077 18:00:00   Thursday  18:00:00
# 2      America/Chicago  20/02/2038 09:00:00   Saturday  09:00:00
# 3       Asia/Singapore  01/01/2031 08:00:00  Wednesday  08:00:00
# 4       Asia/Singapore  01/01/2031 08:00:00  Wednesday  08:00:00

# %%
df_date = df[['day','dtime', 'partecipanti']] #define new dataframe for explore with viz
df_date.head() #check
# Out:
#          day     dtime  partecipanti
# 0     Friday  10:00:00             1
# 1   Thursday  18:00:00             2
# 2   Saturday  09:00:00             1
# 3  Wednesday  08:00:00             1
# 4  Wednesday  08:00:00             1

# %%
df_date['day'] = pd.Categorical(df_date['day'], ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"])
#sorting the days of the week
# Out:
# C:\Users\fabri\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_date.head()
# Out:
#          day     dtime  partecipanti
# 0     Friday  10:00:00             1
# 1   Thursday  18:00:00             2
# 2   Saturday  09:00:00             1
# 3  Wednesday  08:00:00             1
# 4  Wednesday  08:00:00             1

# %%
df_day = df[['day','partecipanti']].groupby('day', as_index = False).sum()
df_time = df[['dtime', 'partecipanti']].groupby('dtime', as_index = False).sum()
df_day
# Out:
#          day  partecipanti
# 0     Friday        126261
# 1     Monday        101700
# 2   Saturday        268015
# 3     Sunday        157555
# 4   Thursday        210401
# 5    Tuesday        195264
# 6  Wednesday        212696

# %%
df_time
# Out:
#        dtime  partecipanti
# 0   00:00:00          1525
# 1   01:00:00           308
# 2   02:00:00           178
# 3   03:00:00           274
# 4   04:00:00           154
# 5   05:00:00           616
# 6   06:00:00          3017
# 7   07:00:00         12921
# 8   08:00:00         30557
# 9   09:00:00         61701
# 10  10:00:00         81833
# 11  11:00:00         56458
# 12  12:00:00         48278
# 13  13:00:00         42332
# 14  14:00:00         43631
# 15  15:00:00         35962
# 16  16:00:00         30342
# 17  17:00:00         53307
# 18  18:00:00        250229
# 19  19:00:00        388109
# 20  20:00:00         93742
# 21  21:00:00         24556
# 22  22:00:00          9248
# 23  23:00:00          2614

# %%
rcParams['figure.figsize'] = 4,6
sns.set(rc = {'axes.facecolor' : '#EAF2F8','axes.edgecolor' : 'white',
              'grid.linewidth': 1, 'grid.color':'white'})
sns.despine(left = True, bottom = True)
ax1 = sns.barplot('partecipanti', 'day', data = df_day, color = '#8E44AD', order = ['Monday', 'Thursday', 'Wednesday',
                                                                               'Tuesday', 'Friday', 'Saturday', 'Sunday'])
ax1.set_ylabel('')
ax1.set(yticklabels = [])
ax1.set_xlabel("Partecipanti", fontsize = 20)
# Out:
# Text(0.5,0,'Partecipanti')

# %%
rcParams['figure.figsize'] = 18,4
sns.set(rc = {'axes.facecolor' : '#EAF2F8','axes.edgecolor' : 'white',
              'grid.linewidth': 1, 'grid.color':'white'})
sns.despine(left = True, bottom = True)
ax = sns.barplot('dtime', 'partecipanti', data = df_time, color = '#8E44AD')
ax.set_xlabel('')
ax.set(xticklabels = [])
ax.set_ylabel("Partecipanti", fontsize = 20)
# Out:
# Text(0,0.5,'Partecipanti')

# %%
#ax1.figure.savefig("C:/Users/fabri/OneDrive/Desktop/barplotdx.png")
#ax.figure.savefig("C:/Users/fabri/OneDrive/Desktop/barplotsup.png")
