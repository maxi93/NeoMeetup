# %%
from __future__ import unicode_literals

import requests
import json
import time
import codecs
import sys

import pandas as pd

# %%
UTF8Writer = codecs.getwriter('utf8')
sys.stdout = UTF8Writer(sys.stdout)

# %%
member_df=pd.read_csv("../Csv/Struttura/member.csv")
#member_df.head()

# %%
member_ids=member_df['member_id']
member_try=[6,7]
#member_ids.head()

# %%
def main():

        
        api_key= "546938372953301546964e404246e"
        # Get your key here https://secure.meetup.com/meetup_api/key/
        for count,id_ in enumerate(member_ids):
            per_page = 1
            #results_we_got = per_page
            offset = 0
            # Meetup.com documentation here: http://www.meetup.com/meetup_api/docs/2/groups/
            response=get_results({"member_id":id_, "key":api_key, "page":per_page, "offset":offset})
            time.sleep(0.01)
            offset += 1
            #results_we_got = response['meta']['count']              
            #time.sleep(1)
            count+=1
            if count is 200:
                break

# %%
def get_results(params):

    request = requests.get("http://api.meetup.com/2/members",params=params)
    data = request.json()
    print(data)
    #iter_data=json.load(data)
    #a=data['results']
    #print(a)
    #for elem in a:
        #print(elem['topics'])
    return data

# %%
# %time
if __name__=="__main__":
        main()
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 5.25 µs
# {'results': [{'country': 'us', 'city': 'Floral Park', 'topics': [{'urlkey': 'outdoor-soccer', 'name': 'Outdoor Soccer', 'id': 24517}, {'urlkey': 'co-ed-soccer', 'name': 'Co-ed Soccer', 'id': 40728}, {'urlkey': 'mens-pick-up-soccer', 'name': 'Mens Pick Up Soccer', 'id': 709522}, {'urlkey': 'coed-soccer', 'name': 'Coed Soccer', 'id': 20557}], 'joined': 1536960299000, 'link': 'http://www.meetup.com/members/263302780', 'photo': {'highres_link': 'https://secure.meetupstatic.com/photos/member/f/d/0/highres_280744048.jpeg', 'photo_id': 280744048, 'base_url': 'https://secure.meetupstatic.com', 'type': 'member', 'photo_link': 'https://secure.meetupstatic.com/photos/member/f/d/0/member_280744048.jpeg', 'thumb_link': 'https://secure.meetupstatic.com/photos/member/f/d/0/thumb_280744048.jpeg'}, 'lon': -73.71, 'other_services': {}, 'name': 'Collins Nkimbeng', 'visited': 1554950213000, 'self': {'common': {}}, 'id': 263302780, 'state': 'NY', 'lat': 40.72, 'status': 'active'}], 'meta': {'next': '', 'method': 'Members', 'total_count': 1, 'link': 'https://api.meetup.com/2/members', 'count': 1, 'description': 'API method for accessing members of Meetup Groups', 'lon': '', 'title': 'Meetup Members v2', 'url': 'https://api.meetup.com/2/members?member_id=263302780&offset=0&format=json&page=1&key=546938372953301546964e404246e&order=name', 'id': '', 'updated': 1537553195000, 'lat': ''}}
# {'results': [{'country': 'us', 'city': 'Millis', 'topics': [{'urlkey': 'modeling', 'name': 'Modeling', 'id': 6144}, {'urlkey': 'wellness', 'name': 'Wellness', 'id': 10306}, {'urlkey': 'folk', 'name': 'Folk Music', 'id': 132}, {'urlkey': 'outdoors', 'name': 'Outdoors', 'id': 15046}, {'urlkey': 'self-improvement', 'name': 'Self-Improvement', 'id': 3336}, {'urlkey': 'fiction', 'name': 'Fiction', 'id': 15113}, {'urlkey': 'dance-lessons', 'name': 'Dance Lessons', 'id': 19146}, {'urlkey': 'fun-times', 'name': 'Fun Times', 'id': 15117}, {'urlkey': 'travel', 'name': 'Travel', 'id': 1998}, {'urlkey': 'bookclub', 'name': 'Book Club', 'id': 2767}, {'urlkey': 'language', 'name': 'Language & Culture', 'id': 10454}, {'urlkey': 'social-dancing', 'name': 'Social Dancing', 'id': 24854}, {'urlkey': 'nature-photography', 'name': 'Nature Photography', 'id': 16600}, {'urlkey': 'literature', 'name': 'Literature', 'id': 15321}, {'urlkey': 'creative-writing', 'name': 'Creative Writing', 'id': 15322}, {'urlkey': 'nature', 'name': 'Nature', 'id': 197471}, {'urlkey': 'poetry', 'name': 'Poetry', 'id': 222}, {'urlkey': 'photo', 'name': 'Photography', 'id': 223}, {'urlkey': 'womens-support', 'name': "Women's Support", 'id': 144477}, {'urlkey': 'happy-hours', 'name': 'Happy Hour', 'id': 16800}, {'urlkey': 'localpolitics', 'name': 'Local Politics', 'id': 8867}, {'urlkey': 'authors', 'name': 'Authors', 'id': 15844}, {'urlkey': 'self-empowerment', 'name': 'Self-Empowerment', 'id': 38757}, {'urlkey': 'culture-exchange', 'name': 'Culture Exchange', 'id': 67622}, {'urlkey': 'intellectual-discussion', 'name': 'Intellectual Discussion', 'id': 15083}, {'urlkey': 'movies', 'name': 'Watching Movies', 'id': 1201}, {'urlkey': 'non-fiction', 'name': 'Non-Fiction', 'id': 22129}, {'urlkey': 'exploring', 'name': 'Exploring', 'id': 17522}, {'urlkey': 'international-travel', 'name': 'International Travel', 'id': 16179}, {'urlkey': 'books-and-drinks', 'name': 'Books and Drinks', 'id': 38966}, {'urlkey': 'weekend-adventures', 'name': 'Weekend Adventures', 'id': 16438}, {'urlkey': 'screenwriters', 'name': 'Screenwriting', 'id': 567}, {'urlkey': 'community-building', 'name': 'Community Building', 'id': 20727}, {'urlkey': 'spanish', 'name': 'Spanish Language', 'id': 183}, {'urlkey': 'learning', 'name': 'Learning', 'id': 18296}, {'urlkey': 'drinking', 'name': 'Drinking', 'id': 15546}, {'urlkey': 'conversation', 'name': 'Conversation', 'id': 15099}, {'urlkey': 'pets-animals', 'name': 'Pets', 'id': 53052}, {'urlkey': 'food-and-drink', 'name': 'Food and Drink', 'id': 87548}, {'urlkey': 'activism', 'name': 'Activism', 'id': 19197}, {'urlkey': 'hiking', 'name': 'Hiking', 'id': 638}, {'urlkey': 'game-night', 'name': 'Game Night', 'id': 40126}, {'urlkey': 'poker', 'name': 'Poker', 'id': 254}], 'joined': 1538092039000, 'link': 'http://www.meetup.com/members/264241156', 'photo': {'highres_link': 'https://secure.meetupstatic.com/photos/member/e/5/7/0/highres_281038736.jpeg', 'photo_id': 281038736, 'base_url': 'https://secure.meetupstatic.com', 'type': 'member', 'photo_link': 'https://secure.meetupstatic.com/photos/member/e/5/7/0/member_281038736.jpeg', 'thumb_link': 'https://secure.meetupstatic.com/photos/member/e/5/7/0/thumb_281038736.jpeg'}, 'lon': -71.36, 'other_services': {}, 'name': 'Sarah Ann', 'visited': 1554644613000, 'self': {'common': {}}, 'id': 264241156, 'state': 'MA', 'lat': 42.17, 'status': 'active'}], 'meta': {'next': '', 'method': 'Members', 'total_count': 1, 'link': 'https://api.meetup.com/2/members', 'count': 1, 'description': 'API method for accessing members of Meetup Groups', 'lon': '', 'title': 'Meetup Members v2', 'url': 'https://api.meetup.com/2/members?member_id=264241156&offset=0&format=json&page=1&key=546938372953301546964e404246e&order=name', 'id': '', 'updated': 1546397874000, 'lat': ''}}
# {'results': [{'country': 'gb', 'city': 'London', 'topics': [], 'joined': 1267135351000, 'link': 'http://www.meetup.com/members/11534341', 'lon': -0.1, 'other_services': {}, 'name': 'Kevin ', 'visited': 1554485097000, 'self': {'common': {}}, 'id': 11534341, 'state': '17', 'lat': 51.52, 'status': 'active'}], 'meta': {'next': '', 'method': 'Members', 'total_count': 1, 'link': 'https://api.meetup.com/2/members', 'count': 1, 'description': 'API method for accessing members of Meetup Groups', 'lon': '', 'title': 'Meetup Members v2', 'url': 'https://api.meetup.com/2/members?member_id=11534341&offset=0&format=json&page=1&key=546938372953301546964e404246e&order=name', 'id': '', 'updated': 1502878874000, 'lat': ''}}
# {'results': [{'country': 'us', 'city': 'New York', 'topics': [{'urlkey': 'meetup', 'name': 'Meetup', 'id': 1787}, {'urlkey': 'photo', 'name': 'Photography', 'id': 223}, {'urlkey': 'rightsforall', 'name': 'Rights for All', 'id': 1965}, {'urlkey': 'writing', 'name': 'Writing', 'id': 16728}, {'urlkey': 'movement', 'name': 'Social Movements', 'id': 10460}, {'urlkey': 'beardedcollie', 'name': 'Bearded Collie', 'id': 2374}, {'urlkey': 'running', 'name': 'Running', 'id': 2516}, {'urlkey': 'economics', 'name': 'Economics', 'id': 3737}, {'urlkey': 'badminton', 'name': 'Badminton', 'id': 2906}, {'urlkey': 'moms', 'name': 'Moms', 'id': 407}, {'urlkey': 'dads', 'name': 'Dads', 'id': 468}, {'urlkey': 'permaculture', 'name': 'Permaculture', 'id': 2527}, {'urlkey': 'newurbanism', 'name': 'New Urbanism', 'id': 3135}, {'urlkey': 'buylocal', 'name': 'Buy Local', 'id': 7008}, {'urlkey': 'localissues', 'name': 'Local Issues', 'id': 9280}, {'urlkey': 'parents', 'name': 'Parents', 'id': 10333}, {'urlkey': 'local-food', 'name': 'Local Food', 'id': 25083}, {'urlkey': 'french-playgroup', 'name': 'French Playgroup', 'id': 39081}, {'urlkey': 'humanrights', 'name': 'Human Rights', 'id': 1546}, {'urlkey': 'outdoors', 'name': 'Outdoors', 'id': 15046}, {'urlkey': 'user-experience', 'name': 'User Experience', 'id': 19243}, {'urlkey': 'product-management', 'name': 'Product Management', 'id': 93740}, {'urlkey': 'technology', 'name': 'Technology', 'id': 10579}, {'urlkey': 'locavesting', 'name': 'Locavesting', 'id': 693202}, {'urlkey': 'playgroup', 'name': 'Playdates', 'id': 9853}, {'urlkey': 'ixd', 'name': 'Interaction Design', 'id': 10110}, {'urlkey': 'community-building', 'name': 'Community Building', 'id': 20727}, {'urlkey': 'experience-design', 'name': 'Experience Design', 'id': 112315}, {'urlkey': 'collaborative-consumption', 'name': 'Collaborative Consumption', 'id': 119047}, {'urlkey': 'crowdfunding', 'name': 'Crowdfunding', 'id': 22816}, {'urlkey': 'kickstarter', 'name': 'Kickstarter', 'id': 103937}, {'urlkey': 'bluegrass', 'name': 'Bluegrass', 'id': 136}, {'urlkey': 'acoustic-jams', 'name': 'Acoustic Jams', 'id': 40464}, {'urlkey': 'philosophy', 'name': 'Philosophy', 'id': 849}, {'urlkey': 'humanism', 'name': 'Humanism', 'id': 1789}, {'urlkey': 'mobile-technology', 'name': 'Mobile Technology', 'id': 16216}, {'urlkey': 'sustainability', 'name': 'Sustainability', 'id': 15998}, {'urlkey': 'newtech', 'name': 'New Technology', 'id': 9696}, {'urlkey': 'intellectual-discussion', 'name': 'Intellectual Discussion', 'id': 15083}, {'urlkey': 'art', 'name': 'Art', 'id': 1502}, {'urlkey': 'dancing', 'name': 'Dancing', 'id': 17571}, {'urlkey': 'localization', 'name': 'Localization', 'id': 32553}, {'urlkey': 'creativecircle', 'name': 'Creative Circle', 'id': 10447}, {'urlkey': 'will-carlough', 'name': 'Will Carlough', 'id': 122537}, {'urlkey': 'productdesign', 'name': 'Product Design', 'id': 2993}, {'urlkey': 'opensource', 'name': 'Open Source', 'id': 563}, {'urlkey': 'mobile-development', 'name': 'Mobile Development', 'id': 21441}, {'urlkey': 'design-patterns', 'name': 'Design Patterns', 'id': 42204}, {'urlkey': 'ai', 'name': 'Artificial Intelligence', 'id': 456}, {'urlkey': 'ux-design', 'name': 'UX Design', 'id': 61781}], 'joined': 1024071214000, 'link': 'http://www.meetup.com/members/6', 'photo': {'highres_link': 'https://secure.meetupstatic.com/photos/member/b/0/e/9/highres_264705289.jpeg', 'photo_id': 264705289, 'base_url': 'https://secure.meetupstatic.com', 'type': 'member', 'photo_link': 'https://secure.meetupstatic.com/photos/member/b/0/e/9/member_264705289.jpeg', 'thumb_link': 'https://secure.meetupstatic.com/photos/member/b/0/e/9/thumb_264705289.jpeg'}, 'lon': -74, 'other_services': {'twitter': {'identifier': '@heif'}}, 'name': 'Scott Heiferman', 'visited': 1554907691000, 'self': {'common': {}}, 'id': 6, 'state': 'NY', 'lat': 40.73, 'status': 'active'}], 'meta': {'next': '', 'method': 'Members', 'total_count': 1, 'link': 'https://api.meetup.com/2/members',  ...
# {'results': [{'country': 'us', 'city': 'Silver Spring', 'topics': [{'urlkey': 'africanamerauth', 'name': 'African-American Authors', 'id': 2304}, {'urlkey': 'classical', 'name': 'Classical Music', 'id': 133}, {'urlkey': 'self-improvement', 'name': 'Self-Improvement', 'id': 3336}, {'urlkey': 'fiction', 'name': 'Fiction', 'id': 15113}, {'urlkey': 'fun-times', 'name': 'Fun Times', 'id': 15117}, {'urlkey': 'womens-empowerment', 'name': "Women's Empowerment", 'id': 17933}, {'urlkey': 'social-dancing', 'name': 'Social Dancing', 'id': 24854}, {'urlkey': 'vegan', 'name': 'Vegan', 'id': 408}, {'urlkey': 'naturalhair', 'name': 'Natural Hair', 'id': 9754}, {'urlkey': 'fashion-entrepreneurs-sharing-successful-secrets', 'name': 'Fashion Entrepreneurs', 'id': 19355}, {'urlkey': 'investing', 'name': 'Investing', 'id': 1307}, {'urlkey': 'psychology', 'name': 'Psychology', 'id': 3485}, {'urlkey': 'excercise', 'name': 'Exercise', 'id': 25375}, {'urlkey': 'happy-hours', 'name': 'Happy Hour', 'id': 16800}, {'urlkey': 'walkers', 'name': 'Walking', 'id': 933}, {'urlkey': 'prodev', 'name': 'Professional Development', 'id': 3880}, {'urlkey': 'karaoke', 'name': 'Karaoke', 'id': 1193}, {'urlkey': 'meditation', 'name': 'Meditation', 'id': 1322}, {'urlkey': 'indianmusic', 'name': 'Indian Music', 'id': 9131}, {'urlkey': 'musicians', 'name': 'Musicians', 'id': 173}, {'urlkey': 'healthy-eating', 'name': 'Healthy Eating', 'id': 19630}, {'urlkey': 'startup-businesses', 'name': 'Startup Businesses', 'id': 21681}, {'urlkey': 'critical-thinking', 'name': 'Critical Thinking', 'id': 15544}, {'urlkey': 'eating-drinking-talking-laughing-etc', 'name': 'Eating, Drinking, Talking, Laughing, Etc', 'id': 19130}, {'urlkey': 'fashion-design', 'name': 'Fashion Design', 'id': 21437}, {'urlkey': 'blackbiz', 'name': 'Black Professionals', 'id': 2494}, {'urlkey': 'fashion-and-style', 'name': 'Fashion and Style', 'id': 16575}, {'urlkey': 'wellness', 'name': 'Wellness', 'id': 10306}, {'urlkey': 'diy', 'name': 'DIY (Do It Yourself)', 'id': 10438}, {'urlkey': 'diningout', 'name': 'Dining Out', 'id': 713}, {'urlkey': 'latin-dance', 'name': 'Latin Dance', 'id': 17993}, {'urlkey': 'black-women', 'name': 'Black Women', 'id': 18634}, {'urlkey': 'dance-lessons', 'name': 'Dance Lessons', 'id': 19146}, {'urlkey': 'african-american-women', 'name': 'African American Women', 'id': 27978}, {'urlkey': 'livemusic', 'name': 'Live Music', 'id': 8652}, {'urlkey': 'travel', 'name': 'Travel', 'id': 1998}, {'urlkey': 'argentine-tango', 'name': 'Argentine Tango', 'id': 20559}, {'urlkey': 'samba', 'name': 'Samba', 'id': 8146}, {'urlkey': 'sports', 'name': 'Sports and Recreation', 'id': 10451}, {'urlkey': 'concerts', 'name': 'Concerts', 'id': 18909}, {'urlkey': 'newtech', 'name': 'New Technology', 'id': 9696}, {'urlkey': 'wine', 'name': 'Wine', 'id': 611}, {'urlkey': 'business-strategy', 'name': 'Business Strategy', 'id': 17635}, {'urlkey': 'self-empowerment', 'name': 'Self-Empowerment', 'id': 38757}, {'urlkey': 'recreational-sports', 'name': 'Recreational Sports', 'id': 131178}, {'urlkey': 'intellectual-discussion', 'name': 'Intellectual Discussion', 'id': 15083}, {'urlkey': 'weightloss', 'name': 'Weight Loss', 'id': 240}, {'urlkey': 'dance-and-movement', 'name': 'Dance and Movement', 'id': 34160}, {'urlkey': 'fitness', 'name': 'Fitness', 'id': 242}, {'urlkey': 'craftswap', 'name': 'Crafts', 'id': 10099}], 'joined': 1545774068000, 'link': 'http://www.meetup.com/members/270532609', 'photo': {'highres_link': 'https://secure.meetupstatic.com/photos/member/3/3/5/4/highres_283513140.jpeg', 'photo_id': 283513140, 'base_url': 'https://secure.meetupstatic.com', 'type': 'member', 'photo_link': 'https://secure.meetupstatic.com/photos/member/3/3/5/4/member_283513140.jpeg', 'thumb_link': 'https://secure.meetupstatic.com/photos/member/3/3/5/4/thumb_283513140.jpeg'}, 'lon': -77.06, 'other_services': {}, 'name': 'Tynaia Taylor', 'visited': 1554911154000, 'self': {'common': {}}, 'id': 270532609, 'state': 'MD', 'lat': 3 ...
# {'results': [{'country': 'us', 'city': 'Raleigh', 'topics': [{'urlkey': 'sports', 'name': 'Sports and Recreation', 'id': 10451}, {'urlkey': 'tennis', 'name': 'Tennis', 'id': 2926}, {'urlkey': 'social-tennis', 'name': 'tennis', 'id': 17700}, {'urlkey': 'pick-up-tennis', 'name': 'Pick-up Tennis', 'id': 158684}, {'urlkey': 'fitness', 'name': 'Fitness', 'id': 242}, {'urlkey': 'outdoors', 'name': 'Outdoors', 'id': 15046}, {'urlkey': 'outdoor-tennis', 'name': 'Outdoor Tennis', 'id': 19954}, {'urlkey': 'excercise', 'name': 'Exercise', 'id': 25375}, {'urlkey': 'competitive-tennis', 'name': 'Competitive Tennis', 'id': 50954}, {'urlkey': 'indoor-tennis', 'name': 'Indoor Tennis', 'id': 112625}, {'urlkey': 'exchicago', 'name': 'Ex-Chicagoans', 'id': 2286}, {'urlkey': 'empty-nesters', 'name': 'Empty Nesters', 'id': 20807}, {'urlkey': 'handmade-crafts', 'name': 'Handmade Crafts', 'id': 16459}], 'joined': 1395449344000, 'link': 'http://www.meetup.com/members/138412042', 'photo': {'highres_link': 'https://secure.meetupstatic.com/photos/member/4/d/1/b/highres_243979739.jpeg', 'photo_id': 243979739, 'base_url': 'https://secure.meetupstatic.com', 'type': 'member', 'photo_link': 'https://secure.meetupstatic.com/photos/member/4/d/1/b/member_243979739.jpeg', 'thumb_link': 'https://secure.meetupstatic.com/photos/member/4/d/1/b/thumb_243979739.jpeg'}, 'lon': -78.64, 'other_services': {}, 'name': 'Brad', 'visited': 1554930178000, 'self': {'common': {}}, 'id': 138412042, 'state': 'NC', 'lat': 35.77, 'status': 'active'}], 'meta': {'next': '', 'method': 'Members', 'total_count': 1, 'link': 'https://api.meetup.com/2/members', 'count': 1, 'description': 'API method for accessing members of Meetup Groups', 'lon': '', 'title': 'Meetup Members v2', 'url': 'https://api.meetup.com/2/members?member_id=138412042&offset=0&format=json&page=1&key=546938372953301546964e404246e&order=name', 'id': '', 'updated': 1528139754000, 'lat': ''}}
# {'results': [{'country': 'us', 'city': 'Portland', 'topics': [{'urlkey': 'smallbiz', 'name': 'Small Business', 'id': 389}, {'urlkey': 'professional-networking', 'name': 'Professional Networking', 'id': 15720}, {'urlkey': 'small-business-networking', 'name': 'Small Business Networking', 'id': 20301}, {'urlkey': 'small-business-owners', 'name': 'Small Business Owners', 'id': 20743}], 'joined': 1212198346000, 'link': 'http://www.meetup.com/members/7340048', 'bio': 'An Independent Associate with LegalShield.  Offering a high-quality, cost-effective legal service and identity theft service.  Plans for individuals, families and small businesses!  Our IDShield Plan is the MOST comprehensive plan in North America!', 'photo': {'highres_link': 'https://secure.meetupstatic.com/photos/member/1/3/8/highres_54240312.jpeg', 'photo_id': 54240312, 'base_url': 'https://secure.meetupstatic.com', 'type': 'member', 'photo_link': 'https://secure.meetupstatic.com/photos/member/1/3/8/member_54240312.jpeg', 'thumb_link': 'https://secure.meetupstatic.com/photos/member/1/3/8/thumb_54240312.jpeg'}, 'lon': -122.6, 'other_services': {}, 'name': 'Kathleen Hjort', 'visited': 1552682048000, 'self': {'common': {}}, 'id': 7340048, 'state': 'OR', 'lat': 45.54, 'status': 'active'}], 'meta': {'next': '', 'method': 'Members', 'total_count': 1, 'link': 'https://api.meetup.com/2/members', 'count': 1, 'description': 'API method for accessing members of Meetup Groups', 'lon': '', 'title': 'Meetup Members v2', 'url': 'https://api.meetup.com/2/members?member_id=7340048&offset=0&format=json&page=1&key=546938372953301546964e404246e&order=name', 'id': '', 'updated': 1552682048000, 'lat': ''}}
# {'results': [{'country': 'in', 'city': 'Kolkata', 'topics': [{'urlkey': 'international-friends', 'name': 'International Friends', 'id': 50881}, {'urlkey': 'wellness', 'name': 'Wellness', 'id': 10306}, {'urlkey': 'outdoors', 'name': 'Outdoors', 'id': 15046}, {'urlkey': 'diy', 'name': 'DIY (Do It Yourself)', 'id': 10438}, {'urlkey': 'self-improvement', 'name': 'Self-Improvement', 'id': 3336}, {'urlkey': 'handmade-crafts', 'name': 'Handmade Crafts', 'id': 16459}, {'urlkey': 'fun-times', 'name': 'Fun Times', 'id': 15117}, {'urlkey': 'big-data', 'name': 'Big Data', 'id': 18062}, {'urlkey': 'travel', 'name': 'Travel', 'id': 1998}, {'urlkey': 'machine-learning', 'name': 'Machine Learning', 'id': 29971}, {'urlkey': 'adventure', 'name': 'Adventure', 'id': 15892}, {'urlkey': 'courses-and-workshops', 'name': 'Courses and Workshops', 'id': 20629}, {'urlkey': 'language', 'name': 'Language & Culture', 'id': 10454}, {'urlkey': 'graduate-students', 'name': 'Graduate Students', 'id': 49687}, {'urlkey': 'writing', 'name': 'Writing', 'id': 16728}, {'urlkey': 'trading', 'name': 'Trading', 'id': 26906}, {'urlkey': 'creative-writing', 'name': 'Creative Writing', 'id': 15322}, {'urlkey': 'poetry', 'name': 'Poetry', 'id': 222}, {'urlkey': 'seo-search-engine-optimization', 'name': 'SEO (Search Engine Optimization)', 'id': 23199}, {'urlkey': 'online-marketing', 'name': 'Online Marketing', 'id': 15585}, {'urlkey': 'english-language', 'name': 'English Language', 'id': 25698}, {'urlkey': 'edtech', 'name': 'Education & Technology', 'id': 7203}, {'urlkey': 'business-strategy', 'name': 'Business Strategy', 'id': 17635}, {'urlkey': 'authors', 'name': 'Authors', 'id': 15844}, {'urlkey': 'language-exchange', 'name': 'Language Exchange', 'id': 26212}, {'urlkey': 'culture-exchange', 'name': 'Culture Exchange', 'id': 67622}, {'urlkey': 'prodev', 'name': 'Professional Development', 'id': 3880}, {'urlkey': 'partying', 'name': 'Partying', 'id': 20137}, {'urlkey': 'gardening', 'name': 'Gardening', 'id': 234}, {'urlkey': 'businessintell', 'name': 'Business Intelligence', 'id': 10538}, {'urlkey': 'intellectual-discussion', 'name': 'Intellectual Discussion', 'id': 15083}, {'urlkey': 'fear-of-public-speaking', 'name': 'Fear of Public Speaking', 'id': 42862}, {'urlkey': 'web-security', 'name': 'Web Security', 'id': 15471}, {'urlkey': 'makers', 'name': 'Makers', 'id': 43887}, {'urlkey': 'cruising', 'name': 'Cruises', 'id': 19056}, {'urlkey': 'startup-businesses', 'name': 'Startup Businesses', 'id': 21681}, {'urlkey': 'nutrition', 'name': 'Nutrition', 'id': 10161}, {'urlkey': 'esl', 'name': 'English as a Second Language', 'id': 182}, {'urlkey': 'weekend-adventures', 'name': 'Weekend Adventures', 'id': 16438}, {'urlkey': 'writing-workshops', 'name': 'Writing Workshops', 'id': 18167}, {'urlkey': 'softwaredev', 'name': 'Software Development', 'id': 3833}, {'urlkey': 'healthy-living', 'name': 'Healthy Living', 'id': 20221}, {'urlkey': 'hiking', 'name': 'Hiking', 'id': 638}, {'urlkey': 'psychology', 'name': 'Psychology', 'id': 3485}, {'urlkey': 'debates', 'name': 'Debate', 'id': 833952}, {'urlkey': 'sexual-education', 'name': 'Sexual Education', 'id': 20591}, {'urlkey': 'business-referral-networking', 'name': 'Business Referral Networking', 'id': 15405}, {'urlkey': 'smallbiz', 'name': 'Small Business', 'id': 389}, {'urlkey': 'publicspeaking', 'name': 'Public Speaking', 'id': 9300}, {'urlkey': 'innovation', 'name': 'Innovation', 'id': 1954}], 'joined': 1541732037000, 'link': 'http://www.meetup.com/members/267386898', 'photo': {'highres_link': 'https://secure.meetupstatic.com/photos/member/4/4/f/7/highres_282257655.jpeg', 'photo_id': 282257655, 'base_url': 'https://secure.meetupstatic.com', 'type': 'member', 'photo_link': 'https://secure.meetupstatic.com/photos/member/4/4/f/7/member_282257655.jpeg', 'thumb_link': 'https://secure.meetupstatic.com/photos/member/4/4/f/7/thumb_282257655.jpeg'}, 'lon': 88.37, 'other_services': {}, 'name': 'Samim Mallick', 'visited': 1553616505000, 'self ...
# {'results': [{'country': 'us', 'hometown': 'Alington', 'city': 'Arlington', 'topics': [], 'joined': 1212198438000, 'link': 'http://www.meetup.com/members/7340053', 'photo': {'highres_link': 'https://secure.meetupstatic.com/photos/member/4/9/c/1/highres_283638881.jpeg', 'photo_id': 283638881, 'base_url': 'https://secure.meetupstatic.com', 'type': 'member', 'photo_link': 'https://secure.meetupstatic.com/photos/member/4/9/c/1/member_283638881.jpeg', 'thumb_link': 'https://secure.meetupstatic.com/photos/member/4/9/c/1/thumb_283638881.jpeg'}, 'lon': -77.14, 'other_services': {}, 'name': 'Yvette', 'visited': 1554169579000, 'self': {'common': {}}, 'id': 7340053, 'state': 'VA', 'lat': 38.88, 'status': 'active'}], 'meta': {'next': '', 'method': 'Members', 'total_count': 1, 'link': 'https://api.meetup.com/2/members', 'count': 1, 'description': 'API method for accessing members of Meetup Groups', 'lon': '', 'title': 'Meetup Members v2', 'url': 'https://api.meetup.com/2/members?member_id=7340053&offset=0&format=json&page=1&key=546938372953301546964e404246e&order=name', 'id': '', 'updated': 1546228189000, 'lat': ''}}
# {'results': [{'country': 'us', 'city': 'Cupertino', 'topics': [{'urlkey': 'fitness', 'name': 'Fitness', 'id': 242}, {'urlkey': 'hiking', 'name': 'Hiking', 'id': 638}, {'urlkey': 'diningout', 'name': 'Dining Out', 'id': 713}, {'urlkey': 'walkers', 'name': 'Walking', 'id': 933}, {'urlkey': 'movies', 'name': 'Watching Movies', 'id': 1201}, {'urlkey': 'travel', 'name': 'Travel', 'id': 1998}, {'urlkey': 'livemusic', 'name': 'Live Music', 'id': 8652}, {'urlkey': 'outdoors', 'name': 'Outdoors', 'id': 15046}, {'urlkey': 'dancing', 'name': 'Dancing', 'id': 17571}, {'urlkey': 'dating-and-relationships', 'name': 'Dating and Relationships', 'id': 20246}, {'urlkey': 'live-theatre', 'name': 'Theater', 'id': 23274}, {'urlkey': 'cooking-any-and-all-kinds-of-cooking', 'name': 'Cooking', 'id': 43256}, {'urlkey': 'movie-nights', 'name': 'Movie Nights', 'id': 15940}, {'urlkey': 'night-life-social-movies-fun-games-night', 'name': 'Night Life, Social, Movies, Fun & Games Night', 'id': 26733}, {'urlkey': 'meditation', 'name': 'Meditation', 'id': 1322}, {'urlkey': 'socializing-for-40', 'name': 'Socializing for 40+', 'id': 16181}, {'urlkey': 'language', 'name': 'Language & Culture', 'id': 10454}, {'urlkey': 'european-culture', 'name': 'European Culture', 'id': 21184}, {'urlkey': 'greek-friends', 'name': 'Greek Friends', 'id': 108751}, {'urlkey': 'classical', 'name': 'Classical Music', 'id': 133}, {'urlkey': 'social-events-for-50-singles', 'name': 'Social events for 50+ singles', 'id': 24400}, {'urlkey': 'nature-appreciation', 'name': 'Nature Appreciation', 'id': 28591}, {'urlkey': 'museums-galleries-exhibitions', 'name': 'Museums-Galleries-Exhibitions', 'id': 1178362}, {'urlkey': 'performing-arts', 'name': 'Performing Arts', 'id': 17558}, {'urlkey': 'recipes', 'name': 'Recipes', 'id': 50709}, {'urlkey': 'city-walks', 'name': 'City Walks', 'id': 113737}, {'urlkey': 'self-improvement', 'name': 'Self-Improvement', 'id': 3336}, {'urlkey': 'stress-relief', 'name': 'Stress Relief', 'id': 17075}, {'urlkey': 'eating-drinking-talking-laughing-etc', 'name': 'Eating, Drinking, Talking, Laughing, Etc', 'id': 19130}, {'urlkey': 'communication-skills', 'name': 'Communication Skills', 'id': 20923}, {'urlkey': 'museums-galleries', 'name': 'Museums & Galleries', 'id': 117248}], 'joined': 1348003860000, 'link': 'http://www.meetup.com/members/62914582', 'photo': {'highres_link': 'https://secure.meetupstatic.com/photos/member/3/d/1/b/highres_249255643.jpeg', 'photo_id': 249255643, 'base_url': 'https://secure.meetupstatic.com', 'type': 'member', 'photo_link': 'https://secure.meetupstatic.com/photos/member/3/d/1/b/member_249255643.jpeg', 'thumb_link': 'https://secure.meetupstatic.com/photos/member/3/d/1/b/thumb_249255643.jpeg'}, 'lon': -122.04, 'other_services': {}, 'name': 'Lydia W.', 'visited': 1554792817000, 'self': {'common': {}}, 'id': 62914582, 'state': 'CA', 'lat': 37.31, 'status': 'active'}], 'meta': {'next': '', 'method': 'Members', 'total_count': 1, 'link': 'https://api.meetup.com/2/members', 'count': 1, 'description': 'API method for accessing members of Meetup Groups', 'lon': '', 'title': 'Meetup Members v2', 'url': 'https://api.meetup.com/2/members?member_id=62914582&offset=0&format=json&page=1&key=546938372953301546964e404246e&order=name', 'id': '', 'updated': 1517105420000, 'lat': ''}}
# {'results': [{'country': 'us', 'city': 'Vallejo', 'topics': [], 'joined': 1488686054000, 'link': 'http://www.meetup.com/members/223171929', 'photo': {'highres_link': 'https://secure.meetupstatic.com/photos/member/c/5/0/a/highres_264830442.jpeg', 'photo_id': 264830442, 'base_url': 'https://secure.meetupstatic.com', 'type': 'member', 'photo_link': 'https://secure.meetupstatic.com/photos/member/c/5/0/a/member_264830442.jpeg', 'thumb_link': 'https://secure.meetupstatic.com/photos/member/c/5/0/a/thumb_264830442.jpeg'}, 'lon': -122.28, 'other_services': {}, 'name': 'Christine B', 'visited': 1554585008000, 'self': {'common': {}}, 'id': 223171929, 'state': 'CA', 'lat': 38.1, 'status': 'active'}], 'meta': {'next': '', 'method': 'Members', 'total_count': 1, 'link': 'https://api.meetup.com/2/members', 'count': 1, 'description': 'API method for accessing members of Meetup Groups', 'lon': '', 'title': 'Meetup Members v2', 'url': 'https://api.meetup.com/2/members?member_id=223171929&offset=0&format=json&page=1&key=546938372953301546964e404246e&order=name', 'id': '', 'updated': 1552343577000, 'lat': ''}}
# {'results': [{'country': 'us', 'city': 'Washington', 'topics': [], 'joined': 1527988752000, 'link': 'http://www.meetup.com/members/255852569', 'photo': {'highres_link': 'https://secure.meetupstatic.com/photos/member/8/0/b/9/highres_279392953.jpeg', 'photo_id': 279392953, 'base_url': 'https://secure.meetupstatic.com', 'type': 'member', 'photo_link': 'https://secure.meetupstatic.com/photos/member/8/0/b/9/member_279392953.jpeg', 'thumb_link': 'https://secure.meetupstatic.com/photos/member/8/0/b/9/thumb_279392953.jpeg'}, 'lon': -77.02, 'other_services': {}, 'name': 'Bob Cornish ', 'visited': 1553291506000, 'self': {'common': {}}, 'id': 255852569, 'state': 'DC', 'lat': 38.91, 'status': 'active'}], 'meta': {'next': '', 'method': 'Members', 'total_count': 1, 'link': 'https://api.meetup.com/2/members', 'count': 1, 'description': 'API method for accessing members of Meetup Groups', 'lon': '', 'title': 'Meetup Members v2', 'url': 'https://api.meetup.com/2/members?member_id=255852569&offset=0&format=json&page=1&key=546938372953301546964e404246e&order=name', 'id': '', 'updated': 1553291494000, 'lat': ''}}
# {'results': [{'country': 'us', 'city': 'Elk Grove', 'topics': [], 'joined': 1521823740000, 'link': 'http://www.meetup.com/members/250837711', 'photo': {'highres_link': 'https://secure.meetupstatic.com/photos/member/5/e/7/4/highres_275784180.jpeg', 'photo_id': 275784180, 'base_url': 'https://secure.meetupstatic.com', 'type': 'member', 'photo_link': 'https://secure.meetupstatic.com/photos/member/5/e/7/4/member_275784180.jpeg', 'thumb_link': 'https://secure.meetupstatic.com/photos/member/5/e/7/4/thumb_275784180.jpeg'}, 'lon': -121.28, 'other_services': {}, 'name': 'Wing Chan', 'visited': 1554645521000, 'self': {'common': {}}, 'id': 250837711, 'state': 'CA', 'lat': 38.44, 'status': 'active'}], 'meta': {'next': '', 'method': 'Members', 'total_count': 1, 'link': 'https://api.meetup.com/2/members', 'count': 1, 'description': 'API method for accessing members of Meetup Groups', 'lon': '', 'title': 'Meetup Members v2', 'url': 'https://api.meetup.com/2/members?member_id=250837711&offset=0&format=json&page=1&key=546938372953301546964e404246e&order=name', 'id': '', 'updated': 1521824069000, 'lat': ''}}
# {'results': [{'country': 'us', 'city': 'San Diego', 'topics': [{'urlkey': 'soccer', 'name': 'Soccer', 'id': 947}], 'joined': 1526690587000, 'link': 'http://www.meetup.com/members/254804002', 'photo': {'highres_link': 'https://secure.meetupstatic.com/photos/member/8/e/d/f/highres_286776575.jpeg', 'photo_id': 286776575, 'base_url': 'https://secure.meetupstatic.com', 'type': 'member', 'photo_link': 'https://secure.meetupstatic.com/photos/member/8/e/d/f/member_286776575.jpeg', 'thumb_link': 'https://secure.meetupstatic.com/photos/member/8/e/d/f/thumb_286776575.jpeg'}, 'lon': -117.07, 'other_services': {}, 'name': 'Thekinghassan', 'visited': 1554279190000, 'self': {'common': {}}, 'id': 254804002, 'state': 'CA', 'lat': 32.8, 'status': 'active'}], 'meta': {'next': '', 'method': 'Members', 'total_count': 1, 'link': 'https://api.meetup.com/2/members', 'count': 1, 'description': 'API method for accessing members of Meetup Groups', 'lon': '', 'title': 'Meetup Members v2', 'url': 'https://api.meetup.com/2/members?member_id=254804002&offset=0&format=json&page=1&key=546938372953301546964e404246e&order=name', 'id': '', 'updated': 1554279253000, 'lat': ''}}
# {'results': [{'country': 'ca', 'city': 'Toronto', 'topics': [{'urlkey': 'newtech', 'name': 'New Technology', 'id': 9696}, {'urlkey': 'innovation', 'name': 'Innovation', 'id': 1954}, {'urlkey': 'business-strategy', 'name': 'Business Strategy', 'id': 17635}, {'urlkey': 'fashion', 'name': 'Fashion Industry', 'id': 1924}, {'urlkey': 'blockchain', 'name': 'Blockchain', 'id': 1493232}, {'urlkey': 'intellectual-discussion', 'name': 'Intellectual Discussion', 'id': 15083}, {'urlkey': 'technology-startups', 'name': 'Technology Startups', 'id': 108403}, {'urlkey': 'internet-ecommerce', 'name': 'E-Commerce', 'id': 27954}, {'urlkey': 'machine-learning', 'name': 'Machine Learning', 'id': 29971}, {'urlkey': 'softwaredev', 'name': 'Software Development', 'id': 3833}, {'urlkey': 'communication-skills', 'name': 'Communication Skills', 'id': 20923}, {'urlkey': 'college-students', 'name': 'College Students', 'id': 29723}], 'joined': 1545774118000, 'link': 'http://www.meetup.com/members/270532644', 'photo': {'highres_link': 'https://secure.meetupstatic.com/photos/member/3/3/5/b/highres_283513147.jpeg', 'photo_id': 283513147, 'base_url': 'https://secure.meetupstatic.com', 'type': 'member', 'photo_link': 'https://secure.meetupstatic.com/photos/member/3/3/5/b/member_283513147.jpeg', 'thumb_link': 'https://secure.meetupstatic.com/photos/member/3/3/5/b/thumb_283513147.jpeg'}, 'lon': -79.36, 'other_services': {}, 'name': 'Carlton Osinde', 'visited': 1549414247000, 'self': {'common': {}}, 'id': 270532644, 'state': 'ON', 'lat': 43.74, 'status': 'active'}], 'meta': {'next': '', 'method': 'Members', 'total_count': 1, 'link': 'https://api.meetup.com/2/members', 'count': 1, 'description': 'API method for accessing members of Meetup Groups', 'lon': '', 'title': 'Meetup Members v2', 'url': 'https://api.meetup.com/2/members?member_id=270532644&offset=0&format=json&page=1&key=546938372953301546964e404246e&order=name', 'id': '', 'updated': 1545774334000, 'lat': ''}}
# {'results': [{'country': 'kr', 'city': 'Euijeongbu', 'topics': [{'urlkey': 'reading', 'name': 'Reading', 'id': 15360}, {'urlkey': 'international-friends', 'name': 'International Friends', 'id': 50881}, {'urlkey': 'wellness', 'name': 'Wellness', 'id': 10306}, {'urlkey': 'movie-nights', 'name': 'Movie Nights', 'id': 15940}, {'urlkey': 'volunteering', 'name': 'Volunteering', 'id': 16645}, {'urlkey': 'outdoors', 'name': 'Outdoors', 'id': 15046}, {'urlkey': 'working-abroad', 'name': 'Working Abroad', 'id': 208971}, {'urlkey': 'self-improvement', 'name': 'Self-Improvement', 'id': 3336}, {'urlkey': 'diningout', 'name': 'Dining Out', 'id': 713}, {'urlkey': 'fun-times', 'name': 'Fun Times', 'id': 15117}, {'urlkey': 'travel', 'name': 'Travel', 'id': 1998}, {'urlkey': 'bookclub', 'name': 'Book Club', 'id': 2767}, {'urlkey': 'philosophy', 'name': 'Philosophy', 'id': 849}, {'urlkey': 'social', 'name': 'Social', 'id': 10581}, {'urlkey': 'language', 'name': 'Language & Culture', 'id': 10454}, {'urlkey': 'business-entrepreneur-networking', 'name': 'Entrepreneur Networking', 'id': 20060}, {'urlkey': 'excercise', 'name': 'Exercise', 'id': 25375}, {'urlkey': 'english-language', 'name': 'English Language', 'id': 25698}, {'urlkey': 'business-strategy', 'name': 'Business Strategy', 'id': 17635}, {'urlkey': 'language-exchange', 'name': 'Language Exchange', 'id': 26212}, {'urlkey': 'self-empowerment', 'name': 'Self-Empowerment', 'id': 38757}, {'urlkey': 'culture-exchange', 'name': 'Culture Exchange', 'id': 67622}, {'urlkey': 'prodev', 'name': 'Professional Development', 'id': 3880}, {'urlkey': 'recreational-sports', 'name': 'Recreational Sports', 'id': 131178}, {'urlkey': 'entrepreneurship', 'name': 'Entrepreneurship', 'id': 19882}, {'urlkey': 'movies', 'name': 'Watching Movies', 'id': 1201}, {'urlkey': 'startup-businesses', 'name': 'Startup Businesses', 'id': 21681}, {'urlkey': 'fitness', 'name': 'Fitness', 'id': 242}, {'urlkey': 'film', 'name': 'Film', 'id': 15029}, {'urlkey': 'esl', 'name': 'English as a Second Language', 'id': 182}, {'urlkey': 'eating-drinking-talking-laughing-etc', 'name': 'Eating, Drinking, Talking, Laughing, Etc', 'id': 19130}, {'urlkey': 'food-and-drink', 'name': 'Food and Drink', 'id': 87548}, {'urlkey': 'healthy-living', 'name': 'Healthy Living', 'id': 20221}], 'joined': 1530925283000, 'link': 'http://www.meetup.com/members/258309770', 'photo': {'highres_link': 'https://secure.meetupstatic.com/photos/member/5/d/0/5/highres_278663813.jpeg', 'photo_id': 278663813, 'base_url': 'https://secure.meetupstatic.com', 'type': 'member', 'photo_link': 'https://secure.meetupstatic.com/photos/member/5/d/0/5/member_278663813.jpeg', 'thumb_link': 'https://secure.meetupstatic.com/photos/member/5/d/0/5/thumb_278663813.jpeg'}, 'lon': 127.04, 'other_services': {}, 'name': 'Tom Lee', 'visited': 1539607927000, 'self': {'common': {}}, 'id': 258309770, 'lat': 37.74, 'status': 'active'}], 'meta': {'next': '', 'method': 'Members', 'total_count': 1, 'link': 'https://api.meetup.com/2/members', 'count': 1, 'description': 'API method for accessing members of Meetup Groups', 'lon': '', 'title': 'Meetup Members v2', 'url': 'https://api.meetup.com/2/members?member_id=258309770&offset=0&format=json&page=1&key=546938372953301546964e404246e&order=name', 'id': '', 'updated': 1530925409000, 'lat': ''}}
# {'results': [{'country': 'fr', 'city': 'Paris', 'topics': [], 'joined': 1546637544000, 'link': 'http://www.meetup.com/members/271231665', 'photo': {'highres_link': 'https://secure.meetupstatic.com/photos/member/9/4/a/d/highres_283778061.jpeg', 'photo_id': 283778061, 'base_url': 'https://secure.meetupstatic.com', 'type': 'member', 'photo_link': 'https://secure.meetupstatic.com/photos/member/9/4/a/d/member_283778061.jpeg', 'thumb_link': 'https://secure.meetupstatic.com/photos/member/9/4/a/d/thumb_283778061.jpeg'}, 'lon': 2.34, 'other_services': {}, 'name': 'Seddik Jaballah', 'visited': 1552937666000, 'self': {'common': {}}, 'id': 271231665, 'lat': 48.86, 'status': 'active'}], 'meta': {'next': '', 'method': 'Members', 'total_count': 1, 'link': 'https://api.meetup.com/2/members', 'count': 1, 'description': 'API method for accessing members of Meetup Groups', 'lon': '', 'title': 'Meetup Members v2', 'url': 'https://api.meetup.com/2/members?member_id=271231665&offset=0&format=json&page=1&key=546938372953301546964e404246e&order=name', 'id': '', 'updated': 1548150166000, 'lat': ''}}
# {'results': [{'country': 'fr', 'city': 'Paris', 'topics': [{'urlkey': 'devops', 'name': 'DevOps', 'id': 87614}, {'urlkey': 'cloud-computing', 'name': 'Cloud Computing', 'id': 15167}, {'urlkey': 'docker', 'name': 'Docker', 'id': 1454542}, {'urlkey': 'sre', 'name': 'SRE', 'id': 1516577}, {'urlkey': 'immutable-infrastructure', 'name': 'Immutable Infrastructure', 'id': 1515096}, {'urlkey': 'microservices', 'name': 'Microservices', 'id': 1504699}], 'joined': 1516458869000, 'link': 'http://www.meetup.com/members/246415405', 'bio': 'Engineering student @ESIEA\n\nI love design, from infrastructure to code and UX', 'photo': {'highres_link': 'https://secure.meetupstatic.com/photos/member/e/7/8/f/highres_275279279.jpeg', 'photo_id': 275279279, 'base_url': 'https://secure.meetupstatic.com', 'type': 'member', 'photo_link': 'https://secure.meetupstatic.com/photos/member/e/7/8/f/member_275279279.jpeg', 'thumb_link': 'https://secure.meetupstatic.com/photos/member/e/7/8/f/thumb_275279279.jpeg'}, 'lon': 2.34, 'other_services': {}, 'name': 'Vincent Gilles', 'visited': 1554892373000, 'self': {'common': {}}, 'id': 246415405, 'lat': 48.86, 'status': 'active'}], 'meta': {'next': '', 'method': 'Members', 'total_count': 1, 'link': 'https://api.meetup.com/2/members', 'count': 1, 'description': 'API method for accessing members of Meetup Groups', 'lon': '', 'title': 'Meetup Members v2', 'url': 'https://api.meetup.com/2/members?member_id=246415405&offset=0&format=json&page=1&key=546938372953301546964e404246e&order=name', 'id': '', 'updated': 1535142677000, 'lat': ''}}
# {'results': [{'country': 'us', 'city': 'Saint Petersburg', 'topics': [{'urlkey': 'diningout', 'name': 'Dining Out', 'id': 713}, {'urlkey': 'dinner-and-a-movie', 'name': 'Dinner and a Movie', 'id': 23778}, {'urlkey': 'travel', 'name': 'Travel', 'id': 1998}], 'joined': 1501246701000, 'link': 'http://www.meetup.com/members/232783918', 'photo': {'highres_link': 'https://secure.meetupstatic.com/photos/member/7/d/0/1/highres_269192001.jpeg', 'photo_id': 269192001, 'base_url': 'https://secure.meetupstatic.com', 'type': 'member', 'photo_link': 'https://secure.meetupstatic.com/photos/member/7/d/0/1/member_269192001.jpeg', 'thumb_link': 'https://secure.meetupstatic.com/photos/member/7/d/0/1/thumb_269192001.jpeg'}, 'lon': -82.75, 'other_services': {}, 'name': 'Janice Shick', 'visited': 1554828827000, 'self': {'common': {}}, 'id': 232783918, 'state': 'FL', 'lat': 27.74, 'status': 'active'}], 'meta': {'next': '', 'method': 'Members', 'total_count': 1, 'link': 'https://api.meetup.com/2/members', 'count': 1, 'description': 'API method for accessing members of Meetup Groups', 'lon': '', 'title': 'Meetup Members v2', 'url': 'https://api.meetup.com/2/members?member_id=232783918&offset=0&format=json&page=1&key=546938372953301546964e404246e&order=name', 'id': '', 'updated': 1501246714000, 'lat': ''}}
# {'results': [{'country': 'us', 'city': 'Brooklyn', 'topics': [{'urlkey': 'soccer', 'name': 'Soccer', 'id': 947}, {'urlkey': 'games', 'name': 'Games', 'id': 15992}, {'urlkey': 'livemusic', 'name': 'Live Music', 'id': 8652}, {'urlkey': 'game-night', 'name': 'Game Night', 'id': 40126}], 'joined': 1545774144000, 'link': 'http://www.meetup.com/members/270532656', 'photo': {'highres_link': 'https://secure.meetupstatic.com/photos/member/3/3/8/1/highres_283513185.jpeg', 'photo_id': 283513185, 'base_url': 'https://secure.meetupstatic.com', 'type': 'member', 'photo_link': 'https://secure.meetupstatic.com/photos/member/3/3/8/1/member_283513185.jpeg', 'thumb_link': 'https://secure.meetupstatic.com/photos/member/3/3/8/1/thumb_283513185.jpeg'}, 'lon': -73.95, 'other_services': {}, 'name': 'Nouri S Rahbe', 'visited': 1551409599000, 'self': {'common': {}}, 'id': 270532656, 'state': 'NY', 'lat': 40.71, 'status': 'active'}], 'meta': {'next': '', 'method': 'Members', 'total_count': 1, 'link': 'https://api.meetup.com/2/members', 'count': 1, 'description': 'API method for accessing members of Meetup Groups', 'lon': '', 'title': 'Meetup Members v2', 'url': 'https://api.meetup.com/2/members?member_id=270532656&offset=0&format=json&page=1&key=546938372953301546964e404246e&order=name', 'id': '', 'updated': 1545774338000, 'lat': ''}}
# {'results': [{'country': 'gb', 'city': 'Brighton', 'topics': [], 'joined': 1450787867000, 'link': 'http://www.meetup.com/members/197132338', 'photo': {'highres_link': 'https://secure.meetupstatic.com/photos/member/8/e/0/c/highres_283716364.jpeg', 'photo_id': 283716364, 'base_url': 'https://secure.meetupstatic.com', 'type': 'member', 'photo_link': 'https://secure.meetupstatic.com/photos/member/8/e/0/c/member_283716364.jpeg', 'thumb_link': 'https://secure.meetupstatic.com/photos/member/8/e/0/c/thumb_283716364.jpeg'}, 'lon': -0.15, 'other_services': {}, 'name': 'Claire', 'visited': 1554916888000, 'self': {'common': {}}, 'id': 197132338, 'state': 'P6', 'lat': 50.83, 'status': 'active'}], 'meta': {'next': '', 'method': 'Members', 'total_count': 1, 'link': 'https://api.meetup.com/2/members', 'count': 1, 'description': 'API method for accessing members of Meetup Groups', 'lon': '', 'title': 'Meetup Members v2', 'url': 'https://api.meetup.com/2/members?member_id=197132338&offset=0&format=json&page=1&key=546938372953301546964e404246e&order=name', 'id': '', 'updated': 1553928994000, 'lat': ''}}
# {'results': [{'country': 'us', 'city': 'Allen', 'topics': [], 'joined': 1543706157000, 'link': 'http://www.meetup.com/members/268959200', 'photo': {'highres_link': 'https://secure.meetupstatic.com/photos/member/8/3/6/2/highres_282873634.jpeg', 'photo_id': 282873634, 'base_url': 'https://secure.meetupstatic.com', 'type': 'member', 'photo_link': 'https://secure.meetupstatic.com/photos/member/8/3/6/2/member_282873634.jpeg', 'thumb_link': 'https://secure.meetupstatic.com/photos/member/8/3/6/2/thumb_282873634.jpeg'}, 'lon': -96.62, 'other_services': {}, 'name': 'BennieSue', 'visited': 1554921044000, 'self': {'common': {}}, 'id': 268959200, 'state': 'TX', 'lat': 33.09, 'status': 'active'}], 'meta': {'next': '', 'method': 'Members', 'total_count': 1, 'link': 'https://api.meetup.com/2/members', 'count': 1, 'description': 'API method for accessing members of Meetup Groups', 'lon': '', 'title': 'Meetup Members v2', 'url': 'https://api.meetup.com/2/members?member_id=268959200&offset=0&format=json&page=1&key=546938372953301546964e404246e&order=name', 'id': '', 'updated': 1553117883000, 'lat': ''}}
# {'results': [{'country': 'us', 'city': 'Kenosha', 'topics': [{'urlkey': 'beer', 'name': 'Beer', 'id': 1475}, {'urlkey': 'cocktails', 'name': 'Cocktails', 'id': 10475}, {'urlkey': 'cigar-aficionado', 'name': 'Cigar Aficionado', 'id': 18482}, {'urlkey': 'diningout', 'name': 'Dining Out', 'id': 713}, {'urlkey': 'food-and-drink', 'name': 'Food and Drink', 'id': 87548}, {'urlkey': 'wine', 'name': 'Wine', 'id': 611}, {'urlkey': 'dating-and-relationships', 'name': 'Dating and Relationships', 'id': 20246}, {'urlkey': 'fun-times', 'name': 'Fun Times', 'id': 15117}, {'urlkey': 'pubs-bars', 'name': 'Pubs and Bars', 'id': 19195}], 'joined': 1462289948000, 'link': 'http://www.meetup.com/members/204472374', 'photo': {'highres_link': 'https://secure.meetupstatic.com/photos/member/3/c/9/1/highres_263775505.jpeg', 'photo_id': 263775505, 'base_url': 'https://secure.meetupstatic.com', 'type': 'member', 'photo_link': 'https://secure.meetupstatic.com/photos/member/3/c/9/1/member_263775505.jpeg', 'thumb_link': 'https://secure.meetupstatic.com/photos/member/3/c/9/1/thumb_263775505.jpeg'}, 'lon': -87.83, 'other_services': {}, 'name': 'Bill "Cigarboy" Marshall', 'visited': 1554460857000, 'self': {'common': {}}, 'id': 204472374, 'state': 'WI', 'lat': 42.58, 'status': 'active'}], 'meta': {'next': '', 'method': 'Members', 'total_count': 1, 'link': 'https://api.meetup.com/2/members', 'count': 1, 'description': 'API method for accessing members of Meetup Groups', 'lon': '', 'title': 'Meetup Members v2', 'url': 'https://api.meetup.com/2/members?member_id=204472374&offset=0&format=json&page=1&key=546938372953301546964e404246e&order=name', 'id': '', 'updated': 1492523558000, 'lat': ''}}
# {'results': [{'country': 'au', 'city': 'Gold Coast', 'topics': [{'urlkey': 'walkers', 'name': 'Walking', 'id': 933}, {'urlkey': 'sports', 'name': 'Sports and Recreation', 'id': 10451}, {'urlkey': 'fitness', 'name': 'Fitness', 'id': 242}, {'urlkey': 'outdoor-fitness', 'name': 'Outdoor  Fitness', 'id': 15672}, {'urlkey': 'adventure-travel', 'name': 'Adventure Travel', 'id': 18317}, {'urlkey': 'hiking', 'name': 'Hiking', 'id': 638}, {'urlkey': 'camping', 'name': 'Camping', 'id': 374}, {'urlkey': 'bike', 'name': 'Bicycling', 'id': 579}, {'urlkey': 'backpacking', 'name': 'Backpacking', 'id': 18988}, {'urlkey': 'excercise', 'name': 'Exercise', 'id': 25375}, {'urlkey': 'running', 'name': 'Running', 'id': 2516}, {'urlkey': 'kayaking', 'name': 'Kayaking', 'id': 590}, {'urlkey': 'healthy-living', 'name': 'Healthy Living', 'id': 20221}, {'urlkey': 'snowshoeing', 'name': 'Snowshoeing', 'id': 6696}, {'urlkey': 'international-travel', 'name': 'International Travel', 'id': 16179}, {'urlkey': 'spirituality', 'name': 'Spirituality', 'id': 10290}, {'urlkey': 'autism-spectrum-disorders', 'name': 'Autism spectrum disorders', 'id': 34891}, {'urlkey': 'lawofattraction', 'name': 'Law of Attraction', 'id': 3382}, {'urlkey': 'socialnetwork', 'name': 'Social Networking', 'id': 4422}], 'joined': 1470708307000, 'link': 'http://www.meetup.com/members/210649209', 'photo': {'highres_link': 'https://secure.meetupstatic.com/photos/member/d/2/c/3/highres_280493955.jpeg', 'photo_id': 280493955, 'base_url': 'https://secure.meetupstatic.com', 'type': 'member', 'photo_link': 'https://secure.meetupstatic.com/photos/member/d/2/c/3/member_280493955.jpeg', 'thumb_link': 'https://secure.meetupstatic.com/photos/member/d/2/c/3/thumb_280493955.jpeg'}, 'lon': 153.44, 'other_services': {}, 'name': 'Barbara Lang', 'visited': 1554449637000, 'self': {'common': {}}, 'id': 210649209, 'lat': -28.07, 'status': 'active'}], 'meta': {'next': '', 'method': 'Members', 'total_count': 1, 'link': 'https://api.meetup.com/2/members', 'count': 1, 'description': 'API method for accessing members of Meetup Groups', 'lon': '', 'title': 'Meetup Members v2', 'url': 'https://api.meetup.com/2/members?member_id=210649209&offset=0&format=json&page=1&key=546938372953301546964e404246e&order=name', 'id': '', 'updated': 1554464598000, 'lat': ''}}
# ...
# {'results': [{'country': 'es', 'city': 'Madrid', 'topics': [{'urlkey': 'entrepreneurship', 'name': 'Entrepreneurship', 'id': 19882}, {'urlkey': 'softwaredev', 'name': 'Software Development', 'id': 3833}, {'urlkey': 'php-framework', 'name': 'PHP Framework', 'id': 100119}, {'urlkey': 'php', 'name': 'PHP', 'id': 455}], 'joined': 1522858171000, 'link': 'http://www.meetup.com/members/251658309', 'photo': {'highres_link': 'https://secure.meetupstatic.com/photos/member/8/4/4/2/highres_281673858.jpeg', 'photo_id': 281673858, 'base_url': 'https://secure.meetupstatic.com', 'type': 'member', 'photo_link': 'https://secure.meetupstatic.com/photos/member/8/4/4/2/member_281673858.jpeg', 'thumb_link': 'https://secure.meetupstatic.com/photos/member/8/4/4/2/thumb_281673858.jpeg'}, 'lon': -3.71, 'other_services': {}, 'name': 'Salvador Alfocea', 'visited': 1553126394000, 'self': {'common': {}}, 'id': 251658309, 'lat': 40.42, 'status': 'active'}], 'meta': {'next': '', 'method': 'Members', 'total_count': 1, 'link': 'https://api.meetup.com/2/members', 'count': 1, 'description': 'API method for accessing members of Meetup Groups', 'lon': '', 'title': 'Meetup Members v2', 'url': 'https://api.meetup.com/2/members?member_id=251658309&offset=0&format=json&page=1&key=546938372953301546964e404246e&order=name', 'id': '', 'updated': 1539934045000, 'lat': ''}}
# {'results': [{'country': 'sg', 'city': 'Singapore', 'topics': [], 'joined': 1539233345000, 'link': 'http://www.meetup.com/members/265289798', 'photo': {'highres_link': 'https://secure.meetupstatic.com/photos/member/9/1/a/0/highres_281497280.jpeg', 'photo_id': 281497280, 'base_url': 'https://secure.meetupstatic.com', 'type': 'member', 'photo_link': 'https://secure.meetupstatic.com/photos/member/9/1/a/0/member_281497280.jpeg', 'thumb_link': 'https://secure.meetupstatic.com/photos/member/9/1/a/0/thumb_281497280.jpeg'}, 'lon': 103.85, 'other_services': {}, 'name': 'Calvin Karuniawan Widjaja', 'visited': 1553608532000, 'self': {'common': {}}, 'id': 265289798, 'lat': 1.3, 'status': 'active'}], 'meta': {'next': '', 'method': 'Members', 'total_count': 1, 'link': 'https://api.meetup.com/2/members', 'count': 1, 'description': 'API method for accessing members of Meetup Groups', 'lon': '', 'title': 'Meetup Members v2', 'url': 'https://api.meetup.com/2/members?member_id=265289798&offset=0&format=json&page=1&key=546938372953301546964e404246e&order=name', 'id': '', 'updated': 1539414394000, 'lat': ''}}
# {'results': [{'country': 'ca', 'city': 'Calgary', 'topics': [{'urlkey': 'craftswap', 'name': 'Crafts', 'id': 10099}, {'urlkey': 'business-strategy', 'name': 'Business Strategy', 'id': 17635}], 'joined': 1447186206000, 'link': 'http://www.meetup.com/members/195384673', 'lon': -114.09, 'other_services': {}, 'name': 'paul omlin', 'visited': 1553616430000, 'self': {'common': {}}, 'id': 195384673, 'state': 'AB', 'lat': 51.05, 'status': 'active'}], 'meta': {'next': '', 'method': 'Members', 'total_count': 1, 'link': 'https://api.meetup.com/2/members', 'count': 1, 'description': 'API method for accessing members of Meetup Groups', 'lon': '', 'title': 'Meetup Members v2', 'url': 'https://api.meetup.com/2/members?member_id=195384673&offset=0&format=json&page=1&key=546938372953301546964e404246e&order=name', 'id': '', 'updated': 1497629192000, 'lat': ''}}
# {'results': [{'country': 'us', 'city': 'Winter Springs', 'topics': [{'urlkey': 'boston-artists', 'name': 'Artists', 'id': 16573}, {'urlkey': 'creative', 'name': 'Creativity', 'id': 36229}, {'urlkey': 'diy-technology', 'name': 'DIY Technology', 'id': 153215}, {'urlkey': 'cultural-activities', 'name': 'Cultural Activities', 'id': 23884}, {'urlkey': 'art', 'name': 'Art', 'id': 1502}, {'urlkey': 'diy-projects', 'name': 'DIY Projects', 'id': 843982}, {'urlkey': 'museum', 'name': 'Museum', 'id': 7319}, {'urlkey': 'hacking', 'name': 'Hacking', 'id': 21123}, {'urlkey': 'business-strategy', 'name': 'Business Strategy', 'id': 17635}, {'urlkey': 'diy', 'name': 'DIY (Do It Yourself)', 'id': 10438}, {'urlkey': 'online-marketing', 'name': 'Online Marketing', 'id': 15585}, {'urlkey': 'prodev', 'name': 'Professional Development', 'id': 3880}, {'urlkey': 'professional-women', 'name': 'Professional Women', 'id': 26273}, {'urlkey': 'startup-businesses', 'name': 'Startup Businesses', 'id': 21681}, {'urlkey': 'sewing-for-beginners', 'name': 'Sewing for Beginners', 'id': 50364}, {'urlkey': 'womens-empowerment', 'name': "Women's Empowerment", 'id': 17933}, {'urlkey': 'women', 'name': "Women's Social", 'id': 10232}, {'urlkey': 'excercise', 'name': 'Exercise', 'id': 25375}, {'urlkey': 'fitness', 'name': 'Fitness', 'id': 242}, {'urlkey': 'information-security', 'name': 'Information Security', 'id': 32743}, {'urlkey': 'newtech', 'name': 'New Technology', 'id': 9696}, {'urlkey': 'social-media', 'name': 'Social Media', 'id': 15401}, {'urlkey': 'softwaredev', 'name': 'Software Development', 'id': 3833}, {'urlkey': 'technology-startups', 'name': 'Technology Startups', 'id': 108403}, {'urlkey': 'webdesign', 'name': 'Web Design', 'id': 659}, {'urlkey': 'creative-writing', 'name': 'Creative Writing', 'id': 15322}, {'urlkey': 'digital-publishing', 'name': 'Digital Publishing', 'id': 25681}, {'urlkey': 'poetry', 'name': 'Poetry', 'id': 222}, {'urlkey': 'seo-for-real-estate-agents-websites', 'name': 'SEO for Real Estate Agents Websites', 'id': 684512}, {'urlkey': 'seo-business-development', 'name': 'SEO Business Development', 'id': 31463}, {'urlkey': 'web-development', 'name': 'Web Development', 'id': 15582}, {'urlkey': 'web-analytics', 'name': 'Web Analytics', 'id': 24439}, {'urlkey': 'web-application', 'name': 'Web Application', 'id': 23836}, {'urlkey': 'web-hosting', 'name': 'Web Hosting', 'id': 42402}, {'urlkey': 'web-design-and-programming', 'name': 'Web design and programming', 'id': 142091}, {'urlkey': 'web-design-and-development', 'name': 'Web Design and Development', 'id': 107225}, {'urlkey': 'web-entrepreneur', 'name': 'Web Entrepreneur', 'id': 136401}, {'urlkey': 'beginner-web-developer', 'name': 'Beginner Web Developer', 'id': 37019}, {'urlkey': 'seo-internet-marketing', 'name': 'Seo & internet Marketing', 'id': 260591}, {'urlkey': 'seo-search-engine-optimization', 'name': 'SEO (Search Engine Optimization)', 'id': 23199}, {'urlkey': 'seo-for-small-businesses', 'name': 'SEO for Small Businesses', 'id': 90585}, {'urlkey': 'real-estate-networking', 'name': 'Real Estate Networking', 'id': 15088}, {'urlkey': 'real-estate', 'name': 'Real Estate', 'id': 18964}, {'urlkey': 'real-estate-investors', 'name': 'Real Estate Investors', 'id': 16165}, {'urlkey': 'real-estate-mentor', 'name': 'Real Estate Mentor', 'id': 17881}, {'urlkey': 'real-estate-staging', 'name': 'Real Estate Staging', 'id': 32524}, {'urlkey': 'real-estate-coaching-and-mentoring', 'name': 'Real Estate Coaching and Mentoring', 'id': 19149}], 'joined': 1459267160000, 'link': 'http://www.meetup.com/members/202375241', 'bio': 'Digital Media Artist', 'photo': {'highres_link': 'https://secure.meetupstatic.com/photos/member/4/f/f/b/highres_259580475.jpeg', 'photo_id': 259580475, 'base_url': 'https://secure.meetupstatic.com', 'type': 'member', 'photo_link': 'https://secure.meetupstatic.com/photos/member/4/f/f/b/member_259580475.jpeg', 'thumb_link': 'https://secure.meetupstatic.com/photos/member/4/f/f/b/ ...
# {'details': 'Credentials have been throttled', 'code': 'throttled', 'problem': 'Client throttled'}
# {'details': 'Credentials have been throttled', 'code': 'throttled', 'problem': 'Client throttled'}
# {'details': 'Credentials have been throttled', 'code': 'throttled', 'problem': 'Client throttled'}
# {'details': 'Credentials have been throttled', 'code': 'throttled', 'problem': 'Client throttled'}
# {'details': 'Credentials have been throttled', 'code': 'throttled', 'problem': 'Client throttled'}
# {'details': 'Credentials have been throttled', 'code': 'throttled', 'problem': 'Client throttled'}
# {'details': 'Credentials have be throttled more than the allowed times in one hour', 'code': 'blocked', 'problem': 'Client throttled'}
# {'details': 'Credentials have be throttled more than the allowed times in one hour', 'code': 'blocked', 'problem': 'Client throttled'}
# {'details': 'Credentials have be throttled more than the allowed times in one hour', 'code': 'blocked', 'problem': 'Client throttled'}
# {'details': 'Credentials have be throttled more than the allowed times in one hour', 'code': 'blocked', 'problem': 'Client throttled'}
# {'details': 'Credentials have be throttled more than the allowed times in one hour', 'code': 'blocked', 'problem': 'Client throttled'}
# {'details': 'Credentials have be throttled more than the allowed times in one hour', 'code': 'blocked', 'problem': 'Client throttled'}
# {'details': 'Credentials have be throttled more than the allowed times in one hour', 'code': 'blocked', 'problem': 'Client throttled'}
# {'details': 'Credentials have be throttled more than the allowed times in one hour', 'code': 'blocked', 'problem': 'Client throttled'}
# {'details': 'Credentials have be throttled more than the allowed times in one hour', 'code': 'blocked', 'problem': 'Client throttled'}
# {'details': 'Credentials have be throttled more than the allowed times in one hour', 'code': 'blocked', 'problem': 'Client throttled'}
# {'details': 'Credentials have be throttled more than the allowed times in one hour', 'code': 'blocked', 'problem': 'Client throttled'}
# {'details': 'Credentials have be throttled more than the allowed times in one hour', 'code': 'blocked', 'problem': 'Client throttled'}
# {'details': 'Credentials have be throttled more than the allowed times in one hour', 'code': 'blocked', 'problem': 'Client throttled'}
# {'details': 'Credentials have be throttled more than the allowed times in one hour', 'code': 'blocked', 'problem': 'Client throttled'}
# {'details': 'Credentials have be throttled more than the allowed times in one hour', 'code': 'blocked', 'problem': 'Client throttled'}
# {'details': 'Credentials have be throttled more than the allowed times in one hour', 'code': 'blocked', 'problem': 'Client throttled'}
# {'details': 'Credentials have be throttled more than the allowed times in one hour', 'code': 'blocked', 'problem': 'Client throttled'}
# {'details': 'Credentials have be throttled more than the allowed times in one hour', 'code': 'blocked', 'problem': 'Client throttled'}
# {'details': 'Credentials have be throttled more than the allowed times in one hour', 'code': 'blocked', 'problem': 'Client throttled'}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-68-772c644eca6e> in <module>
#       1 get_ipython().run_line_magic('time', '')
#       2 if __name__=="__main__":
# ----> 3         main()
#
# <ipython-input-66-c2330b92b805> in main()
#       9             offset = 0
#      10             # Meetup.com documentation here: http://www.meetup.com/meetup_api/docs/2/groups/
# ---> 11             response=get_results({"member_id":id_, "key":api_key, "page":per_page, "offset":offset})
#      12             #time.sleep(0.01)
#      13             offset += 1
#
# <ipython-input-67-39636bcedb62> in get_results(params)
#       1 def get_results(params):
#       2
# ----> 3     request = requests.get("http://api.meetup.com/2/members",params=params)
#       4     data = request.json()
#       5     print(data)
#
# ~/.local/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/.local/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~/.local/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/.local/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/.local/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/.local/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~/.local/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# /usr/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# /usr/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /usr/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# /usr/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
## Run this script and send it into a csv:
## python meetup-pages-names-dates.py > meetup_groups.csv
