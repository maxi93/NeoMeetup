# %%
#!/usr/bin/python
import json
import csv
import ast
from pprint import pprint
#from kafka import KafkaConsumer
import time
import pandas as pd
from pandas import DataFrame as df

# %%
start_t=time.time()

# %%
df = pd.read_csv("../Csv/Struttura/relations_topics.csv")

# %%
df.head()
# Out:
#    group_id  member_id               topic_name                   urlkey
# 0   7764982   11211390             Scuba Diving             scuba-diving
# 1   7764982   11211390               Snorkeling               snorkeling
# 2   7764982   11211390  Environmental Awareness  environmental-awareness
# 3   7764982   11211390        Scuba Instruction        scuba-instruction
# 4   7764982   11211390      Learn to Scuba Dive      learn-to-scuba-dive

# %%
df1= pd.read_csv("../Csv/Struttura/member_enriched.csv")

# %%
df1=df1.drop(columns='Unnamed: 0')

# %%
#df1.head()

# %%
df1.dropna(inplace=True)

# %%
id_list=[]
topic_list=[]
setcount=None
for count,line  in enumerate(df1.itertuples()):
    topics=df1.topics[line.Index]
    tmp_list=topics.split()
    
    for elem in tmp_list:
        #print(line.Index)
        id_list.append(df1['member_id'][line.Index])
        elem=elem.strip("[").strip("]").strip(",")
        elem=elem.replace("'","")
        topic_list.append(elem)
    if setcount:        
        if count is 2:
            break

# %%
df2=pd.DataFrame({"type":1,"group_id":"NaN","member_id":id_list,"topic_name":"NaN","urlkey":topic_list})
#print(len(df2))
df2.head()
# Out:
# 2976173
#    type group_id  member_id topic_name            urlkey
# 0     1      NaN  263302780        NaN          modeling
# 1     1      NaN  263302780        NaN          wellness
# 2     1      NaN  263302780        NaN              folk
# 3     1      NaN  263302780        NaN          outdoors
# 4     1      NaN  263302780        NaN  self-improvement

# %%
df['type']=0
df['type']=df['type'].apply(int)

# %%
df_c=pd.concat([df, df2], sort=False)
df_c.head()
# Out:
#   group_id  member_id               topic_name                   urlkey  type
# 0  7764982   11211390             Scuba Diving             scuba-diving     0
# 1  7764982   11211390               Snorkeling               snorkeling     0
# 2  7764982   11211390  Environmental Awareness  environmental-awareness     0
# 3  7764982   11211390        Scuba Instruction        scuba-instruction     0
# 4  7764982   11211390      Learn to Scuba Dive      learn-to-scuba-dive     0

# %%
df_c.tail()
# Out:
#         group_id  member_id topic_name                urlkey  type
# 2976168      NaN  184549367        NaN  information-security     1
# 2976169      NaN  184549367        NaN                   web     1
# 2976170      NaN  184549367        NaN                 nosql     1
# 2976171      NaN  184549367        NaN        datamanagement     1
# 2976172      NaN  184549367        NaN           databasepro     1

# %%
#print(len(df_c))
#print(len(df2))
#print(len(df))
#print("sum len:"+str(len(df)+len(df2)))
# Out:
# 16985880
# 2976173
# 14009707
# sum len:16985880

# %%
del df

# %%
del df1
del df2

# %%
df_c.sort_values('urlkey', inplace=True)
#df.head()

# %%
df_c.reset_index(inplace=True)

# %%
df_c.drop('index', axis=1, inplace=True)

# %%
df_c['topic_id']=0

temp=df_c.urlkey.at[0]
count=0
index=0


for line in df_c.itertuples():

    curr_url=line.urlkey
    if curr_url == temp:
        df_c['topic_id'].at[line.Index]=count

    else:
        count+=1
        df_c['topic_id'].at[line.Index]=count
        temp=curr_url
    #if count == 20:
    #    break

# %%
# In[9]:


df_c.head(50)
# Out:
#     group_id  member_id                       topic_name  \
# 0   30796503  203532739            1/2 Marathon Training
# 1   30796503   30419082            1/2 Marathon Training
# 2   30796503  233172999            1/2 Marathon Training
# 3   30796503  203532739            1/2 Marathon Training
# 4   30796503  247963215            1/2 Marathon Training
# 5   30796503  254846889            1/2 Marathon Training
# 6   30796503  233172999            1/2 Marathon Training
# 7        NaN  250823691                              NaN
# 8        NaN  193152016                              NaN
# 9   30796503  247963215            1/2 Marathon Training
# 10   8760702   97685372            1/2 Marathon Training
# 11  30796503  247963215            1/2 Marathon Training
# 12  30796503   15682881            1/2 Marathon Training
# 13  30796503  144158912            1/2 Marathon Training
# 14  30796503  122312322            1/2 Marathon Training
# 15  30796503  122312322            1/2 Marathon Training
# 16  30796503   87986032            1/2 Marathon Training
# 17   8760702  254740225            1/2 Marathon Training
# 18       NaN  164722952                              NaN
# 19   8760702  207943153            1/2 Marathon Training
# 20       NaN  229819593                              NaN
# 21   8760702  254740225            1/2 Marathon Training
# 22  30796503  211309929            1/2 Marathon Training
# 23  30796503   87986032            1/2 Marathon Training
# 24       NaN  216038878                              NaN
# 25  30649235   51251352  1 day Travel & Weekend Getaways
# 26       NaN   44121502                              NaN
# 27  30649235   51251352  1 day Travel & Weekend Getaways
# 28  30649235   51251352  1 day Travel & Weekend Getaways
# 29       NaN  214829206                              NaN
# 30       NaN  200214322                              NaN
# 31       NaN  222625168                              NaN
# 32       NaN  189582112                              NaN
# 33       NaN  239156555                              NaN
# 34       NaN  234117030                              NaN
# 35       NaN  236492972                              NaN
# 36       NaN   15030741                              NaN
# 37       NaN  160003032                              NaN
# 38       NaN  103640762                              NaN
# 39  15601782  184057309           100+ Business Startups
# 40       NaN  204121269                              NaN
# 41  15601782  270784187           100+ Business Startups
# 42  15601782   75353122           100+ Business Startups
# 43  24980900  199950102           100+ Business Startups
# 44  15601782   75353122           100+ Business Startups
# 45  15601782  250545745           100+ Business Startups
# 46  15601782   13375304           100+ Business Startups
# 47  15601782  160511782           100+ Business Startups
# 48       NaN  118441992                              NaN
# 49       NaN  266186612                              NaN
#
#                                               urlkey  type  topic_id
# 0                              1-2-marathon-training     0         0
# 1                              1-2-marathon-training     0         0
# 2                              1-2-marathon-training     0         0
# 3                              1-2-marathon-training     0         0
# 4                              1-2-marathon-training     0         0
# 5                              1-2-marathon-training     0         0
# 6                              1-2-marathon-training     0         0
# 7                              1-2-marathon-training     1         0
# 8                              1-2-marathon-training     1         0
# 9                              1-2-marathon-training     0         0
# 10                             1-2-marathon-training     0         0
# 11                             1-2-marathon-training     0         0
# 12                             1-2-marathon-training     0         0
# 13                             1-2-marathon-training     0         0
# 14                             1-2-marathon-training     0         0
# 15                             1-2-marathon-training     0         0
# 16                             1-2-marathon-training     0         0
# 17                             1-2-marathon-training     0         0
# 18                             1-2-marathon-training     1         0
# 19                             1-2-marathon-training     0         0
# 20                             1-2-marathon-training     1         0
# 21                             1-2-marathon-training     0         0
# 22                             1-2-marathon-training     0         0
# 23                             1-2-marathon-training     0         0
# 24                     1-day-travel-weekend-getaways     1         1
# 25                     1-day-travel-weekend-getaways     0         1
# 26                     1-day-travel-weekend-getaways     1         1
# 27                     1-day-travel-weekend-getaways     0         1
# 28                     1-day-travel-weekend-getaways     0         1
# 29                     1-day-travel-weekend-getaways     1         1
# 30                                10-minute-workouts     1         2
# 31                                10-minute-workouts     1         2
# 32  100-black-men-naacp-100-black-women-urban-league     1         3
# 33  100-black-men-naacp-100-black-women-urban-league     1         3
# 34  100-black-men-naacp-100-black-women-urban-league     1         3
# 35  100-black-men-naacp-100-black-women-urban-league     1         3
# 36  100-black-men-naacp-100-black-women-urban-league     1         3
# 37  100-black-men-naacp-100-black-women-urban-league     1         3
# 38  100-black-men-naacp-100-black-women-urban-league     1         3
# 39                             100-business-startups     0         4
# 40                             100-business-startups     1         4
# 41                             100-business-startups     0         4
# 42                             100-business-startups     0         4
# 43                             100-business-startups     0         4
# 44                             100-business-startups     0         4
# 45                             100-business-startups     0         4
# 46                             100-business-startups     0         4
# 47                             100-business-startups     0         4
# 48                             100-business-startups     1         4
# 49                             100-business-startups     1         4

# %%
# In[10]:

time=time.time()-start_t
#print "completed in "+str(time)

# %%
#df_create_topic=pd.DataFrame([df_c['topic_id'],df_c['urlkey']])
df_create_topic=pd.concat([df_c['topic_id'],df_c['urlkey']], axis=1).reset_index() #eventually add topic_name

# %%
df_create_topic.head(50)

# %%
df_create_topic.to_csv("../Csv/Struttura/Create_topic_nodes.csv", index=False)

# %%
del df_create_topic

# %%
df_topic_interest=df_c[df_c['type']==0]

# %%
df_topic_interest.drop(columns='type', inplace=True)

# %%
df_topic_interest.to_csv("../Csv/Struttura/relations_topics_with_id.csv", index=False)

# %%
del df_topic_interest

# %%
df_topic_decleared=df_c[df_c['type']==1]
df_topic_decleared.drop(columns=['type','group_id','topic_name'], inplace=True)
# Out:
# /home/dario/.local/lib/python3.6/site-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
df_topic_decleared.to_csv("../Csv/Struttura/relations_decleared_topics.csv", index=False)
